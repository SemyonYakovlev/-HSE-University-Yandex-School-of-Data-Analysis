# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

close = pd.read_csv('close_prices.csv')
close = close.drop(columns=['date'])
close
# Out:
#            AXP          BA        CAT       CSCO         CVX         DD  \
# 0    76.440002  117.510002  85.029999  24.270000  125.519997  59.409999
# 1    76.070000  119.000000  85.110001  24.139999  124.489998  59.319997
# 2    75.989998  118.510002  84.500000  24.430000  124.070000  59.319997
# 3    76.320000  119.379997  84.199997  23.770000  123.489998  59.509996
# 4    75.889999  118.739998  83.800003  23.330000  122.639999  59.009995
# ..         ...         ...        ...        ...         ...        ...
# 369  81.559998  152.039993  80.190002  28.240000  102.419998  80.400001
# 370  80.599998  151.570007  79.230003  27.940001  101.620003  80.499997
# 371  81.500000  153.669998  79.970001  28.299999  103.129997  77.069994
# 372  81.059998  154.509995  78.449997  28.150000  103.169998  74.680001
# 373  81.860001  155.729996  81.330002  28.150000  106.699997  76.009997
#
#             DIS         GE          GS          HD  ...        PFE         PG  \
# ...

# %%
import numpy as np
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
result = pca.fit(close)

# %%
VAR = 0
count = 0
for i in range(len(result.explained_variance_ratio_)):
    if VAR < 0.9:
        VAR += result.explained_variance_ratio_[i]
        count +=1
count
# Out:
# 4

# %%
proekciya=pca.transform(close)
proekciya
# Out:
# array([[-50.90240358,  17.63167724,   7.7360209 , ...,   3.55657041,
#          -5.82197358,  -1.72604005],
#        [-52.84690919,  19.14690749,   7.27254551, ...,   3.43259929,
#          -5.63318106,  -2.0122316 ],
#        [-54.61443917,  19.92735811,   8.10995831, ...,   4.17520282,
#          -5.38828678,  -2.75269933],
#        ...,
#        [ 83.79819948,  16.95241334,  -8.25265611, ...,   2.92390381,
#          -4.59543822,  -2.99033503],
#        [ 79.19578947,  19.14436008,  -6.93262976, ...,   3.40475421,
#          -3.66793327,  -3.57607629],
#        [ 82.96885933,  13.13513974,  -9.07644299, ...,   3.75100423,
#          -4.79172198,  -3.03918865]])

# %%
index = pd.read_csv('djia_index.csv')
index
# Out:
#            date          ^DJI
# 0    2013-09-23  15401.379883
# 1    2013-09-24  15334.589844
# 2    2013-09-25  15273.259766
# 3    2013-09-26  15328.299805
# 4    2013-09-27  15258.240234
# ..          ...           ...
# 369  2015-03-12  17895.220703
# 370  2015-03-13  17749.310547
# 371  2015-03-16  17977.419922
# 372  2015-03-17  17849.080078
# 373  2015-03-18  18076.189453
#
# [374 rows x 2 columns]

# %%
np.corrcoef(index.iloc[:,1],proekciya[:,0])
# Out:
# array([[1.        , 0.90965222],
#        [0.90965222, 1.        ]])

# %%
firstComponent=pd.DataFrame(data=result.components_[0])
firstComponent['stocks'] = close.columns
firstComponent.sort_values(by=[0],ascending=False)
# Out:
#            0 stocks
# 26  0.579684      V
# 16  0.329616    MMM
# 24  0.321564    UNH
# 9   0.288996     HD
# 8   0.251227     GS
# 6   0.233906    DIS
# 19  0.211889    NKE
# 23  0.189480    TRV
# 1   0.120645     BA
# 5   0.114090     DD
# 11  0.093132   INTC
# 12  0.091395    JNJ
# 28  0.087161    WMT
# 21  0.077732     PG
# 18  0.076230   MSFT
# 17  0.071390    MRK
# 25  0.053683    UTX
# 3   0.050484   CSCO
# 13  0.046988    JPM
# 14  0.029055     KO
# 20  0.023092    PFE
# 0   0.016138    AXP
# 27  0.000109     VZ
# 7  -0.006205     GE
# 22 -0.007206      T
# 15 -0.026107    MCD
# 29 -0.042942    XOM
# 2  -0.051661    CAT
# 4  -0.125860    CVX
# 10 -0.264999    IBM
